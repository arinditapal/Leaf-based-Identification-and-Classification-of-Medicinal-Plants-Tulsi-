# %%
import joblib
import pandas as pd

# %%
model = joblib.load("model.joblib")

# %%
model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 80,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 5,
#  'verbose': 0,
#  'warm_start': False}

# %%
df = pd.read_csv("basil_dataset.csv")
df.head()
# Out:
#           label  green_color  brown_color  green_to_brown_ratio  \
# 0  downy_mildew     2.066458     0.494136              4.181965
# 1  downy_mildew     4.240871     2.100950              2.018550
# 2  downy_mildew     0.000000     1.890563              0.000000
# 3  downy_mildew    59.205965     0.000000              0.000000
# 4  downy_mildew    52.398090     0.000000              0.000000
#
#    perimeter_to_area_ratio  solidity  roundness  aspect_ratio  \
# 0                 0.025388  0.864022   0.156837      1.532847
# 1                 0.033033  0.912588   0.137574      1.828257
# 2                 0.028565  0.916065   0.144819      1.727595
# 3                 0.037495  0.916482   0.163614      1.156194
# 4                 0.026012  0.931384   0.140640      1.136608
#
#                     corr_1                dis_sim_1  ...  \
# 0  {0: 0.9911548766553693}  {0: 1.0402337636932708}  ...
# 1  {0: 0.9864397223207604}  {0: 0.8213810641627544}  ...
# ...

# %%
# take a leaf sample features data from train dataset
leaf_sample = df.iloc[:1]

x = leaf_sample.drop(["label", "image_name", "category"])
y = leaf_sample["label"]
# Out:
#           label  green_color  brown_color  green_to_brown_ratio  \
# 0  downy_mildew     2.066458     0.494136              4.181965
#
#    perimeter_to_area_ratio  solidity  roundness  aspect_ratio  \
# 0                 0.025388  0.864022   0.156837      1.532847
#
#                     corr_1                dis_sim_1  ...  \
# 0  {0: 0.9911548766553693}  {0: 1.0402337636932708}  ...
#
#                  homogen_5               contrast_5                 energy_5  \
# 0  {0: 0.7564540449060428}  {0: 104.02682265307928}  {0: 0.6840053116381063}
#
#                     corr_6                dis_sim_6                homogen_6  \
# 0  {0: 0.9446529448547337}  {0: 3.4642122542620943}  {0: 0.7374488931072247}
#
#                 contrast_6                 energy_6    image_name  \
# 0  {0: 189.39410031248764}  {0: 0.6796225512939529}  downy_mildew
#
#        category
# 0  downy_mildew
#
# [1 rows x 40 columns]
